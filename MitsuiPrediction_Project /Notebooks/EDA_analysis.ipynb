# %% [markdown]
# 主題：MITSUI&CO. Commodity EDA
#
# 問題：分析MITSUI&CO. Commodity資料集，進行探索性資料分析（EDA），以了解資料的結構、特徵和潛在的模式。

# %% [markdown]
# 套件：
# Python,
# Jupyter Notebook,
# Pandas：用於資料處理和分析，提供了高效的資料結構和操作工具。
# Matplotlib：用於資料視覺化，提供了豐富的繪圖功能。
# Seaborn：基於Matplotlib的資料視覺化庫，提供了更高級的繪圖功能和美觀的默認樣式。

# %%
# importing libraries
import pandas as pd 
import numpy as np
from pathlib import Path

# %% [markdown]
# 資料介紹

# %%
# loading data
customers = pd.read_csv('/Users/aditi/Documents/Data_Analysis_Portfolio/MitsuiPrediction_Project /raw_data/olist/olist_customers_dataset.csv') 
orders= pd.read_csv('/Users/aditi/Documents/Data_Analysis_Portfolio/MitsuiPrediction_Project /raw_data/olist/olist_orders_dataset.csv')
orders_items= pd.read_csv('/Users/aditi/Documents/Data_Analysis_Portfolio/MitsuiPrediction_Project /raw_data/olist/olist_order_items_dataset.csv')
orders_payments= pd.read_csv('/Users/aditi/Documents/Data_Analysis_Portfolio/MitsuiPrediction_Project /raw_data/olist/olist_order_payments_dataset.csv')
orders_reviews= pd.read_csv('/Users/aditi/Documents/Data_Analysis_Portfolio/MitsuiPrediction_Project /raw_data/olist/olist_order_reviews_dataset.csv')
geolocation= pd.read_csv('/Users/aditi/Documents/Data_Analysis_Portfolio/MitsuiPrediction_Project /raw_data/olist/olist_geolocation_dataset.csv')
sellers= pd.read_csv('/Users/aditi/Documents/Data_Analysis_Portfolio/MitsuiPrediction_Project /raw_data/olist/olist_sellers_dataset.csv')
product_category_name= pd.read_csv('/Users/aditi/Documents/Data_Analysis_Portfolio/MitsuiPrediction_Project /raw_data/olist/product_category_name_translation.csv')
products= pd.read_csv('/Users/aditi/Documents/Data_Analysis_Portfolio/MitsuiPrediction_Project /raw_data/olist/olist_products_dataset.csv')
# checking data
print(customers.head())
print(orders.head())
print(orders_items.head())
print(orders_payments.head())
print(orders_reviews.head())
print(geolocation.head())
print(sellers.head())
print(product_category_name.head())
print(products.head())
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# ...

# %%
# checking data info
print(customers.info())
print(orders.info())
print(orders_items.info())
print(orders_payments.info())
print(orders_reviews.info())
print(geolocation.info())
print(sellers.info())
print(product_category_name.info())
print(products.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  str
#  1   customer_unique_id        99441 non-null  str
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  str
#  4   customer_state            99441 non-null  str
# dtypes: int64(1), str(4)
# memory usage: 3.8 MB
# None
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  str
#  1   customer_id                    99441 non-null  str
#  2   order_status                   99441 non-null  str
#  3   order_purchase_timestamp       99441 non-null  str
# ...

# %%
# checking data columns
customers.columns.tolist( )
orders.columns.tolist( )
orders_items.columns.tolist( )
orders_payments.columns.tolist( )
orders_reviews.columns.tolist( )
geolocation.columns.tolist( )
sellers.columns.tolist( )
product_category_name.columns.tolist( )
products.columns.tolist( )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 3
#       1 # checking data columns
#       2 customers.columns.tolist( )
# ----> 3 orders.columns.tolist( )
#       4 orders_items.columns.tolist( )
#       5 orders_payments.columns.tolist( )
#
# File <stringsource>:69, in cfunc.to_py.__Pyx_CFunc_b0409f__29_pydevd_sys_monitoring_cython_object__lParen__etc_to_py_4code_4line.wrap()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1481, in _pydevd_sys_monitoring_cython._line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1586, in _pydevd_sys_monitoring_cython._internal_line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1961, in _pydevd_sys_monitoring_cython._do_wait_suspend()
#
# ...
